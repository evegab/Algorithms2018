# %% [markdown]
# ## Solución punto 2 en Python usando numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.int_( 0 )
f1 = np.int_( 1)

n = np.int_( 42 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.intc( 0 )
f1 = np.intc( 1)

n = np.intc( 44 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.intp( 0 )
f1 = np.intp( 1)

n = np.intp( 89 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.int8( 0 )
f1 = np.int8( 1)

n = np.int8( 9 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.int16( 0 )
f1 = np.int16( 1)

n = np.int16( 21 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.int32( 0 )
f1 = np.int32( 1)

n = np.int32( 44 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.int64( 0 )
f1 = np.int64( 1)

n = np.int64( 90 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.uint8( 0 )
f1 = np.uint8( 1)

n = np.uint8( 49 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in ubyte_scalars
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.uint16( 0 )
f1 = np.uint16( 1)

n = np.uint16( 25 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in ushort_scalars
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in ushort_scalars

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

f0 = np.uint32( 0 )
f1 = np.uint32( 1)

n = np.uint64( 49 )
t0 = 0
tf = 0
t1 = 0
listTime = []

for i in range ( 0, int(n + 1) ):
	t0 = time.clock()
	#print "t0 = ", t0
	f1 = f0 + f1
	f0 = f1 - f0
	t1 = time.clock()
	tf = t1 - t0
	listTime.append( tf )
	#print "t1 = ", t1
	#print "tf = ", tf
	#print f1
	
sizeArray = range ( n + 1 ) # lista del 0 to 11 
casoPromedio = listTime

fig = plt.figure()
axes = fig.add_subplot( 111 )
plt.bar( sizeArray, casoPromedio )
plt.ylabel('Tiempo' )
plt.xlabel('Tamano n')
plt.title( "n vs time" )
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in ulong_scalars
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in ulong_scalars
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-778a8052499c> in <module>()
#      24         #print f1
#      25
# ---> 26 sizeArray = range ( n + 1 ) # lista del 0 to 11
#      27 casoPromedio = listTime
#      28
#
# TypeError: range() integer end argument expected, got numpy.float64.
